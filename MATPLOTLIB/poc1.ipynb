# %%
import matplotlib.pyplot as plt
from PIL import Image
lion_img=Image.open(r"C:\pandu\lion.jpg")
lion_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1365>

# %%
import numpy as np

# %%
dog_arr =np.asarray(lion_img)
dog_arr
# Out:
# array([[[251, 248, 241],
#         [251, 248, 241],
#         [251, 248, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        [[251, 248, 241],
#         [251, 248, 241],
#         [252, 247, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        [[251, 248, 241],
#         [251, 248, 241],
#         [252, 247, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        ...,
#
#        [[121,  83,  44],
#         [121,  83,  44],
#         [120,  78,  38],
#         ...,
#         [254, 181, 104],
#         [254, 181, 104],
#         [253, 180, 103]],
#
#        [[125,  87,  48],
#         [122,  84,  45],
#         [118,  76,  36],
#         ...,
#         [255, 182, 105],
#         [254, 181, 104],
#         [254, 181, 104]],
#
#        [[128,  90,  51],
#         [124,  86,  47],
#         [119,  77,  37],
# ...

# %%
print(type(dog_arr))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(dog_arr)

# %%
dog_arr.shape
# Out:
# (1365, 2048, 3)
